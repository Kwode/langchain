# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
model = ChatOpenAI(
    model='gpt-3.5-turbo',
    temperature=0.7,
    max_completion_tokens=100
)

# %%
list_parser = CommaSeparatedListOutputParser()

# %%
chat_template = ChatPromptTemplate.from_messages([('human', 'give me a list of 3 {pet} breeds. '+ \
                                                   CommaSeparatedListOutputParser().get_format_instructions())])

# %%
# chain = chat_template | model | list_parser
# chain.invoke({'pet':'dog'})

# %% [markdown]
# Batching

# %%
batch_chat_template = ChatPromptTemplate.from_messages([('human', 'I just got a {object} for {sport}, Could you suggest training tips?')])

# %%
chain = batch_chat_template | model

# %%
chain.batch([{'object':'ball', 'sport':'basketball'}, {'object':'racket', 'sport':'tennis'}])
# Out:
# [AIMessage(content='Of course! Here are', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 21, 'total_tokens': 26, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DNoipi52qZN4TBj91aWlbAruQvni0', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d2c8c-65e4-7882-9f1d-20c6ad14c61b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 5, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='Of course! Here are', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 21, 'total_tokens': 26, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DNoipsrsTlePPFdFPiDGRY0B0WkIt', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d2c8c-65ea-7c80-b5d7-0f1690e5c75e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 5, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# STREAMING

# %%
response = chain.stream({'object':'ball', 'sport':'basketball'})
for i in response:
    print(i.content, end= "")
# Out:
# Of course! Here are some training tips for basketball:
#
# 1. Dribbling: Practice dribbling the ball with both hands, keeping your head up and eyes forward. Start with stationary dribbling drills and then incorporate moving drills to improve your ball-handling skills.
#
# 2. Shooting: Work on your shooting technique by practicing your form and shot accuracy. Start close to the basket and gradually move further away as you improve. Focus on shooting consistently and with proper form.
#
# 3. Passing: Practice different types

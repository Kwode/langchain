# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
model = ChatOpenAI(
    model='gpt-3.5-turbo',
    temperature=0.7,
    max_completion_tokens=50
)

# %%
chat_1_template = ChatPromptTemplate.from_template("""
list 5 {color} fruits in {country}
""")

# %%
str_parser = StrOutputParser()

# %%
chain_1 = chat_1_template | model | str_parser | {'fruits':RunnablePassthrough(), 'color':RunnablePassthrough()}

# %%
chat_2_template = ChatPromptTemplate.from_template("""
why is {fruits} {color}?
""")

# %%
chain_2 =  chain_1 | chat_2_template | model | str_parser
chain_2.invoke({'country':'algeria', 'color':'red'})
# Out:
# 'These fruits are all red in color, which is likely why they are listed together. They also share similar flavors and are often used in similar types of dishes or recipes. Additionally, they are all known for their health benefits and are commonly used in desserts'
